# %%
import sys
sys.path.insert(1, '../')
import topology_interface_main as tim
import haldane_model as verify
import numpy as np
import matplotlib.pyplot as plt
import scipy.linalg as la
import z2pack
import verification_utils as utils
#import yaehmop_tools

# %% [markdown]
# # Description of Interface Workflow

# %% [raw]
# -Data from POSCAR used to create Yaehmop input file for extended Huckel calculation
# -Yaehmop input file is run, and Hamiltonian, overlap, and occupation are output as a function of k
#     *note Kpoints are automatically generated using tim.generate_k() to ensure kpoints are compatible with z2pack
# -Parser is used to read Hamiltonian, overlap matrix, and occupation into python
# -z2pack.hm.system is built from Hamiltonian, overlap matrix, and occupation
#     *works for 2D and 3D systems
# -z2pack runs calculations and outputs chern number z2 invariant of all surfaces in volume (just one number if system is 2D)
#    more info on how z2pack performs calculations is described in file named z2pack_chapter.pdf

# %% [markdown]
# # Verification of Interface in 1D, 2D using SSH model, Haldane Model, and BHZ model

# %% [markdown]
# # 1D: SSH Model

# %%
from IPython.display import Image
print("The Su-Schrieffer-Heeger (SSH) Model describes trans-polyacetlyene")
print("periodic SSH Hamiltonian Results in a chern number of 1 when t2>t1")
Image(filename="ssh_ham.png")

#source: https://arxiv.org/pdf/1906.08435.pdf
# Out:
# The Su-Schrieffer-Heeger (SSH) Model describes trans-polyacetlyene
# periodic SSH Hamiltonian Results in a chern number of 1 when t2>t1

# %%
Image(filename="ssh_figure.png")

# %%
#Calculating chern number as a function of alpha, t2=alpha*t1
#transition at alpha =1, t1=t2
alpha=np.arange(0.5,2.5,0.1)
fname="ssh_output.OUT"
chern_=[]
for a in alpha:
    k_vect=tim.generate_k_1D(nkx=10)
    hamiltonian=verify.ssh_hamiltonian(a,t1=-1.0)
    #create Mock Yaehmop output file from Hamiltonian Data and kpoints
    verify.write_yaehmop_output_from_ham(fname,k_vect,hamiltonian)
    c,z = tim.get_topology(fname,ham_type="general")
    chern_.append(c)


plt.plot(alpha,chern_)
plt.title("winding number as a function of alpha for SSH Model")
plt.ylabel("winding number")
plt.xlabel("alpha, t2=alpha*t1")
plt.show()
# Out:
# +----------------------------------------------------------------------+
# | ================                                                     |
# | LINE CALCULATION                                                     |
# | ================                                                     |
# | starting at 2021-08-06 15:45:16,590                                  |
# | running Z2Pack version 2.1.1                                         |
# |                                                                      |
# | init_result: None                                                    |
# | iterator:    range(9, 40)                                            |
# | line:        <function get_topology.<locals>.<lambda> at 0x05E6C420> |
# | load:        False                                                   |
# | load_quiet:  True                                                    |
# | pos_tol:     None                                                    |
# | save_file:   None                                                    |
# | serializer:  auto                                                    |
# | system:      <z2pack.hm.System object at 0x0BF55D10>                 |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 9
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                       ==================                             |
# |                       CONVERGENCE REPORT                             |
# |                       ==================                             |
# |                                                                      |
# |                       ForceFirstUpdate: PASSED                       |
# +----------------------------------------------------------------------+
#
# +----------------------------------------------------------------------+
# | ================                                                     |
# | LINE CALCULATION                                                     |
# | ================                                                     |
# | starting at 2021-08-06 15:45:16,607                                  |
# | running Z2Pack version 2.1.1                                         |
# |                                                                      |
# | init_result: None                                                    |
# | iterator:    range(9, 40)                                            |
# | line:        <function get_topology.<locals>.<lambda> at 0x0AED56F0> |
# | load:        False                                                   |
# | load_quiet:  True                                                    |
# | pos_tol:     None                                                    |
# | save_file:   None                                                    |
# | serializer:  auto                                                    |
# | system:      <z2pack.hm.System object at 0x05E63E50>                 |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 9
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                       ==================                             |
# |                       CONVERGENCE REPORT                             |
# |                       ==================                             |
# |                                                                      |
# |                       ForceFirstUpdate: PASSED                       |
# +----------------------------------------------------------------------+
#
# +----------------------------------------------------------------------+
# | ================                                                     |
# | LINE CALCULATION                                                     |
# | ================                                                     |
# | starting at 2021-08-06 15:45:16,625                                  |
# | running Z2Pack version 2.1.1                                         |
# |                                                                      |
# | init_result: None                                                    |
# | iterator:    range(9, 40)                                            |
# | line:        <function get_topology.<locals>.<lambda> at 0x05E6C108> |
# | load:        False                                                   |
# | load_quiet:  True                                                    |
# | pos_tol:     None                                                    |
# | save_file:   None                                                    |
# | serializer:  auto                                                    |
# | system:      <z2pack.hm.System object at 0x0BF55C90>                 |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 9
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                       ==================                             |
# |                       CONVERGENCE REPORT                             |
# |                       ==================                             |
# |                                                                      |
# |                       ForceFirstUpdate: PASSED                       |
# +----------------------------------------------------------------------+
#
# +----------------------------------------------------------------------+
# | ================                                                     |
# | LINE CALCULATION                                                     |
# | ================                                                     |
# | starting at 2021-08-06 15:45:16,640                                  |
# | running Z2Pack version 2.1.1                                         |
# |                                                                      |
# | init_result: None                                                    |
# | iterator:    range(9, 40)                                            |
# | line:        <function get_topology.<locals>.<lambda> at 0x05E6C270> |
# | load:        False                                                   |
# | load_quiet:  True                                                    |
# | pos_tol:     None                                                    |
# | save_file:   None                                                    |
# | serializer:  auto                                                    |
# | system:      <z2pack.hm.System object at 0x05E63810>                 |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 9
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                       ==================                             |
# |                       CONVERGENCE REPORT                             |
# |                       ==================                             |
# |                                                                      |
# |                       ForceFirstUpdate: PASSED                       |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# | ================                                                     |
# | LINE CALCULATION                                                     |
# | ================                                                     |
# | starting at 2021-08-06 15:45:16,659                                  |
# | running Z2Pack version 2.1.1                                         |
# |                                                                      |
# | init_result: None                                                    |
# | iterator:    range(9, 40)                                            |
# | line:        <function get_topology.<locals>.<lambda> at 0x05E6C420> |
# | load:        False                                                   |
# | load_quiet:  True                                                    |
# | pos_tol:     None                                                    |
# | save_file:   None                                                    |
# | serializer:  auto                                                    |
# | system:      <z2pack.hm.System object at 0x0BF55C30>                 |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 9
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                       ==================                             |
# |                       CONVERGENCE REPORT                             |
# |                       ==================                             |
# |                                                                      |
# |                       ForceFirstUpdate: PASSED                       |
# +----------------------------------------------------------------------+
#
# +----------------------------------------------------------------------+
# | ================                                                     |
# | LINE CALCULATION                                                     |
# | ================                                                     |
# | starting at 2021-08-06 15:45:16,690                                  |
# | running Z2Pack version 2.1.1                                         |
# |                                                                      |
# | init_result: None                                                    |
# | iterator:    range(9, 40)                                            |
# | line:        <function get_topology.<locals>.<lambda> at 0x05E6C5D0> |
# | load:        False                                                   |
# | load_quiet:  True                                                    |
# | pos_tol:     None                                                    |
# | save_file:   None                                                    |
# | serializer:  auto                                                    |
# | system:      <z2pack.hm.System object at 0x05E637D0>                 |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 9
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                       ==================                             |
# |                       CONVERGENCE REPORT                             |
# |                       ==================                             |
# |                                                                      |
# |                       ForceFirstUpdate: PASSED                       |
# +----------------------------------------------------------------------+
#
# +----------------------------------------------------------------------+
# | ================                                                     |
# | LINE CALCULATION                                                     |
# | ================                                                     |
# | starting at 2021-08-06 15:45:16,705                                  |
# | running Z2Pack version 2.1.1                                         |
# |                                                                      |
# | init_result: None                                                    |
# | iterator:    range(9, 40)                                            |
# | line:        <function get_topology.<locals>.<lambda> at 0x05E6C5D0> |
# | load:        False                                                   |
# | load_quiet:  True                                                    |
# | pos_tol:     None                                                    |
# | save_file:   None                                                    |
# | serializer:  auto                                                    |
# | system:      <z2pack.hm.System object at 0x0BF55930>                 |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 9
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                       ==================                             |
# |                       CONVERGENCE REPORT                             |
# |                       ==================                             |
# |                                                                      |
# |                       ForceFirstUpdate: PASSED                       |
# +----------------------------------------------------------------------+
#
# +----------------------------------------------------------------------+
# | ================                                                     |
# | LINE CALCULATION                                                     |
# | ================                                                     |
# | starting at 2021-08-06 15:45:16,735                                  |
# | running Z2Pack version 2.1.1                                         |
# |                                                                      |
# | init_result: None                                                    |
# | iterator:    range(9, 40)                                            |
# | line:        <function get_topology.<locals>.<lambda> at 0x05E6C108> |
# | load:        False                                                   |
# | load_quiet:  True                                                    |
# | pos_tol:     None                                                    |
# | save_file:   None                                                    |
# | serializer:  auto                                                    |
# | system:      <z2pack.hm.System object at 0x0BF55C90>                 |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 9
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                       ==================                             |
# |                       CONVERGENCE REPORT                             |
# |                       ==================                             |
# |                                                                      |
# |                       ForceFirstUpdate: PASSED                       |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# | ================                                                     |
# | LINE CALCULATION                                                     |
# | ================                                                     |
# | starting at 2021-08-06 15:45:16,759                                  |
# | running Z2Pack version 2.1.1                                         |
# |                                                                      |
# | init_result: None                                                    |
# | iterator:    range(9, 40)                                            |
# | line:        <function get_topology.<locals>.<lambda> at 0x05E6C270> |
# | load:        False                                                   |
# | load_quiet:  True                                                    |
# | pos_tol:     None                                                    |
# | save_file:   None                                                    |
# | serializer:  auto                                                    |
# | system:      <z2pack.hm.System object at 0x05E637B0>                 |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 9
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                       ==================                             |
# |                       CONVERGENCE REPORT                             |
# |                       ==================                             |
# |                                                                      |
# |                       ForceFirstUpdate: PASSED                       |
# +----------------------------------------------------------------------+
#
# +----------------------------------------------------------------------+
# | ================                                                     |
# | LINE CALCULATION                                                     |
# | ================                                                     |
# | starting at 2021-08-06 15:45:16,793                                  |
# | running Z2Pack version 2.1.1                                         |
# |                                                                      |
# | init_result: None                                                    |
# | iterator:    range(9, 40)                                            |
# | line:        <function get_topology.<locals>.<lambda> at 0x05E6C618> |
# | load:        False                                                   |
# | load_quiet:  True                                                    |
# | pos_tol:     None                                                    |
# | save_file:   None                                                    |
# | serializer:  auto                                                    |
# | system:      <z2pack.hm.System object at 0x05E63D90>                 |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 9
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                       ==================                             |
# |                       CONVERGENCE REPORT                             |
# |                       ==================                             |
# |                                                                      |
# |                       ForceFirstUpdate: PASSED                       |
# +----------------------------------------------------------------------+
#
# +----------------------------------------------------------------------+
# | ================                                                     |
# | LINE CALCULATION                                                     |
# | ================                                                     |
# | starting at 2021-08-06 15:45:16,818                                  |
# | running Z2Pack version 2.1.1                                         |
# |                                                                      |
# | init_result: None                                                    |
# | iterator:    range(9, 40)                                            |
# | line:        <function get_topology.<locals>.<lambda> at 0x05E6C270> |
# | load:        False                                                   |
# | load_quiet:  True                                                    |
# | pos_tol:     None                                                    |
# | save_file:   None                                                    |
# | serializer:  auto                                                    |
# | system:      <z2pack.hm.System object at 0x05E637B0>                 |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 9
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                       ==================                             |
# |                       CONVERGENCE REPORT                             |
# |                       ==================                             |
# |                                                                      |
# |                       ForceFirstUpdate: PASSED                       |
# +----------------------------------------------------------------------+
#
# +----------------------------------------------------------------------+
# | ================                                                     |
# | LINE CALCULATION                                                     |
# | ================                                                     |
# | starting at 2021-08-06 15:45:16,849                                  |
# | running Z2Pack version 2.1.1                                         |
# |                                                                      |
# | init_result: None                                                    |
# | iterator:    range(9, 40)                                            |
# | line:        <function get_topology.<locals>.<lambda> at 0x05E6C618> |
# | load:        False                                                   |
# | load_quiet:  True                                                    |
# | pos_tol:     None                                                    |
# | save_file:   None                                                    |
# | serializer:  auto                                                    |
# | system:      <z2pack.hm.System object at 0x0BF55DF0>                 |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 9
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                       ==================                             |
# |                       CONVERGENCE REPORT                             |
# |                       ==================                             |
# |                                                                      |
# |                       ForceFirstUpdate: PASSED                       |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# | ================                                                     |
# | LINE CALCULATION                                                     |
# | ================                                                     |
# | starting at 2021-08-06 15:45:16,871                                  |
# | running Z2Pack version 2.1.1                                         |
# |                                                                      |
# | init_result: None                                                    |
# | iterator:    range(9, 40)                                            |
# | line:        <function get_topology.<locals>.<lambda> at 0x05E6C5D0> |
# | load:        False                                                   |
# | load_quiet:  True                                                    |
# | pos_tol:     None                                                    |
# | save_file:   None                                                    |
# | serializer:  auto                                                    |
# | system:      <z2pack.hm.System object at 0x0BF7D170>                 |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 9
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                       ==================                             |
# |                       CONVERGENCE REPORT                             |
# |                       ==================                             |
# |                                                                      |
# |                       ForceFirstUpdate: PASSED                       |
# +----------------------------------------------------------------------+
#
# +----------------------------------------------------------------------+
# | ================                                                     |
# | LINE CALCULATION                                                     |
# | ================                                                     |
# | starting at 2021-08-06 15:45:16,889                                  |
# | running Z2Pack version 2.1.1                                         |
# |                                                                      |
# | init_result: None                                                    |
# | iterator:    range(9, 40)                                            |
# | line:        <function get_topology.<locals>.<lambda> at 0x05E6C618> |
# | load:        False                                                   |
# | load_quiet:  True                                                    |
# | pos_tol:     None                                                    |
# | save_file:   None                                                    |
# | serializer:  auto                                                    |
# | system:      <z2pack.hm.System object at 0x05E637B0>                 |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 9
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                       ==================                             |
# |                       CONVERGENCE REPORT                             |
# |                       ==================                             |
# |                                                                      |
# |                       ForceFirstUpdate: PASSED                       |
# +----------------------------------------------------------------------+
#
# +----------------------------------------------------------------------+
# | ================                                                     |
# | LINE CALCULATION                                                     |
# | ================                                                     |
# | starting at 2021-08-06 15:45:16,914                                  |
# | running Z2Pack version 2.1.1                                         |
# |                                                                      |
# | init_result: None                                                    |
# | iterator:    range(9, 40)                                            |
# | line:        <function get_topology.<locals>.<lambda> at 0x05E6C108> |
# | load:        False                                                   |
# | load_quiet:  True                                                    |
# | pos_tol:     None                                                    |
# | save_file:   None                                                    |
# | serializer:  auto                                                    |
# | system:      <z2pack.hm.System object at 0x0BF7D370>                 |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 9
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                       ==================                             |
# |                       CONVERGENCE REPORT                             |
# |                       ==================                             |
# |                                                                      |
# |                       ForceFirstUpdate: PASSED                       |
# +----------------------------------------------------------------------+
#
# +----------------------------------------------------------------------+
# | ================                                                     |
# | LINE CALCULATION                                                     |
# | ================                                                     |
# | starting at 2021-08-06 15:45:16,932                                  |
# | running Z2Pack version 2.1.1                                         |
# |                                                                      |
# | init_result: None                                                    |
# | iterator:    range(9, 40)                                            |
# | line:        <function get_topology.<locals>.<lambda> at 0x05E6C420> |
# | load:        False                                                   |
# | load_quiet:  True                                                    |
# | pos_tol:     None                                                    |
# | save_file:   None                                                    |
# | serializer:  auto                                                    |
# | system:      <z2pack.hm.System object at 0x0BF7D530>                 |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 9
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                       ==================                             |
# |                       CONVERGENCE REPORT                             |
# |                       ==================                             |
# |                                                                      |
# |                       ForceFirstUpdate: PASSED                       |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# | ================                                                     |
# | LINE CALCULATION                                                     |
# | ================                                                     |
# | starting at 2021-08-06 15:45:16,951                                  |
# | running Z2Pack version 2.1.1                                         |
# |                                                                      |
# | init_result: None                                                    |
# | iterator:    range(9, 40)                                            |
# | line:        <function get_topology.<locals>.<lambda> at 0x05E6C270> |
# | load:        False                                                   |
# | load_quiet:  True                                                    |
# | pos_tol:     None                                                    |
# | save_file:   None                                                    |
# | serializer:  auto                                                    |
# | system:      <z2pack.hm.System object at 0x0BF7DFB0>                 |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 9
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                       ==================                             |
# |                       CONVERGENCE REPORT                             |
# |                       ==================                             |
# |                                                                      |
# |                       ForceFirstUpdate: PASSED                       |
# +----------------------------------------------------------------------+
#
# +----------------------------------------------------------------------+
# | ================                                                     |
# | LINE CALCULATION                                                     |
# | ================                                                     |
# | starting at 2021-08-06 15:45:16,969                                  |
# | running Z2Pack version 2.1.1                                         |
# |                                                                      |
# | init_result: None                                                    |
# | iterator:    range(9, 40)                                            |
# | line:        <function get_topology.<locals>.<lambda> at 0x05E6C108> |
# | load:        False                                                   |
# | load_quiet:  True                                                    |
# | pos_tol:     None                                                    |
# | save_file:   None                                                    |
# | serializer:  auto                                                    |
# | system:      <z2pack.hm.System object at 0x0BF7D290>                 |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 9
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                       ==================                             |
# |                       CONVERGENCE REPORT                             |
# |                       ==================                             |
# |                                                                      |
# |                       ForceFirstUpdate: PASSED                       |
# +----------------------------------------------------------------------+
#
# +----------------------------------------------------------------------+
# | ================                                                     |
# | LINE CALCULATION                                                     |
# | ================                                                     |
# | starting at 2021-08-06 15:45:16,988                                  |
# | running Z2Pack version 2.1.1                                         |
# |                                                                      |
# | init_result: None                                                    |
# | iterator:    range(9, 40)                                            |
# | line:        <function get_topology.<locals>.<lambda> at 0x05E6C618> |
# | load:        False                                                   |
# | load_quiet:  True                                                    |
# | pos_tol:     None                                                    |
# | save_file:   None                                                    |
# | serializer:  auto                                                    |
# | system:      <z2pack.hm.System object at 0x0BF7D530>                 |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 9
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                       ==================                             |
# |                       CONVERGENCE REPORT                             |
# |                       ==================                             |
# |                                                                      |
# |                       ForceFirstUpdate: PASSED                       |
# +----------------------------------------------------------------------+
#
# +----------------------------------------------------------------------+
# | ================                                                     |
# | LINE CALCULATION                                                     |
# | ================                                                     |
# | starting at 2021-08-06 15:45:17,006                                  |
# | running Z2Pack version 2.1.1                                         |
# |                                                                      |
# | init_result: None                                                    |
# | iterator:    range(9, 40)                                            |
# | line:        <function get_topology.<locals>.<lambda> at 0x05E6C5D0> |
# | load:        False                                                   |
# | load_quiet:  True                                                    |
# | pos_tol:     None                                                    |
# | save_file:   None                                                    |
# | serializer:  auto                                                    |
# | system:      <z2pack.hm.System object at 0x05E63910>                 |
# +----------------------------------------------------------------------+
#
# INFO: 0 of 1 line convergence criteria fulfilled.
# INFO:       Calculating line for N = 9
# INFO: 1 of 1 line convergence criteria fulfilled.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                       ==================                             |
# |                       CONVERGENCE REPORT                             |
# |                       ==================                             |
# |                                                                      |
# |                       ForceFirstUpdate: PASSED                       |
# +----------------------------------------------------------------------+

# %%
#finite SSH

#create system, set constants
num_unit_cells=4.5
alpha=np.arange(0,4.1,0.1)
e=1
t1=0.1

eigval_vect_dict,ham=utils.vary_alpha(num_unit_cells,alpha)

#plotting eigenvalues
for i,a in enumerate(eigval_vect_dict["eigenvalues"][0,:]):
    color=np.random.rand(3)
    plt.plot(alpha,eigval_vect_dict["eigenvalues"][:,i],label="eigenvalue "+str(i),color=color)
plt.xlabel("alpha")
plt.ylabel("Eigenvalue Energy")
plt.legend(loc="upper right", bbox_to_anchor=(1.3, 0.95))
plt.title("eigenvalue vs. alpha for hopping parameters, alpha=t1/t2")
plt.show()

#introduce noise in t1,t2
eigval_vect_dict,ham=utils.vary_alpha(num_unit_cells,alpha,glass=True)

for i,a in enumerate(eigval_vect_dict["eigenvalues"][0,:]):
    color=np.random.rand(3)
    plt.plot(alpha,eigval_vect_dict["eigenvalues"][:,i],label="eigenvalue "+str(i),color=color)
plt.xlabel("alpha")
plt.ylabel("Eigenvalue Energy")
plt.legend(loc="upper right", bbox_to_anchor=(1.3, 0.95))
plt.title("eigenvalue vs. alpha for hopping parameters, alpha=t1/t2 with random noise in each hopping parameter")
plt.show()

#plotting eigenvectors corresponding to zero energy eigenvalues
r=np.linspace(-num_unit_cells,0,len(eigval_vect_dict["eigenvectors"][0,:]))
a_val=-1
wf1=eigval_vect_dict["eigenvectors"][a_val,:,int(num_unit_cells)] 
wf2=eigval_vect_dict["eigenvectors"][a_val,:,int(num_unit_cells)+1] 
plt.plot(range(int(2*num_unit_cells+1)),wf1,color="red",label="Eigenvector " +str(int(num_unit_cells)))
plt.plot(range(int(2*num_unit_cells+1)),wf2,color="blue",label="Eigenvector " +str(int(num_unit_cells)+1))
plt.title("wave function vs. site number, alpha= "+"{:.2f}".format(alpha[a_val]))
plt.legend(loc="upper right", bbox_to_anchor=(1.4, .95))
plt.show()

print("Key observations:")
print("two eigenvalues converge to zero as alpha is increased even when random noise is introduced --> these are protected states")
print("These zero energy states have wave functions that are localized at the end of the polymer")
# Out:
# Key observations:
# two eigenvalues converge to zero as alpha is increased even when random noise is introduced --> these are protected states
# These zero energy states have wave functions that are localized at the end of the polymer

# %% [markdown]
# # 2D: Haldane Model, non-zero chern number

# %%
print("Haldane Hamiltonian Results in a chern number of 1.0")
print("hamiltonian includes two atom types, first and second neighbor hopping, and a hexagonal lattice")
Image(filename="haldane_ham.png")
#source https://topocondmat.org/w4_haldane/haldane_model.html
# Out:
# Haldane Hamiltonian Results in a chern number of 1.0
# hamiltonian includes two atom types, first and second neighbor hopping, and a hexagonal lattice

# %%
Image(filename="haldane_figure.png")

# %%
#get topology of Haldane model as a test, Haldane model results placed in Yaehmop-like output file to test functions

alpha=np.arange(0.5,4.0,0.1)
m, t1, phi=0.5, 1., 0.5 * np.pi
k_vect=tim.generate_k_2D()
fname="haldane_output.OUT"
chern_=[]
z2_=[]
for a in alpha:
    ham=verify.haldane_hamiltonian(m,t1,t1/a,phi)
    verify.write_yaehmop_output_from_ham(fname,k_vect,ham)
    c, z = tim.get_topology(fname,ham_type="general")
    chern_.append(c)
    z2_.append(z)
chern_=np.array(chern_)
z2_=np.array(z2_)

plt.plot(alpha,chern_)
plt.title("plotting chern number of haldane model as t2 is varied relative to t1")
plt.xlabel("alpha, t2=t1/alpha")
plt.ylabel("chern number")
plt.show()
# Out:
# +----------------------------------------------------------------------+
# |===================                                                   |
# |SURFACE CALCULATION                                                   |
# |===================                                                   |
# |starting at 2021-08-06 15:37:13,923                                   |
# |running Z2Pack version 2.1.1                                          |
# |                                                                      |
# |gap_tol:            None                                              |
# |init_result:        None                                              |
# |iterator:           range(10, 40)                                     |
# |load:               False                                             |
# |load_quiet:         True                                              |
# |min_neighbour_dist: 0.01                                              |
# |move_tol:           None                                              |
# |num_lines:          10                                                |
# |pos_tol:            None                                              |
# |save_file:          None                                              |
# |serializer:         auto                                              |
# |surface:            <function get_topology<...><lambda> at 0x0BB49C90>|
# |system:             <z2pack.hm.System object at 0x0C36B070>           |
# +----------------------------------------------------------------------+
#
# INFO: Adding lines required by 'num_lines'.
# INFO: Adding line at t = 0.0
# INFO:       Calculating line for N = 10
# INFO: Adding line at t = 0.1111111111111111
# INFO:       Calculating line for N = 10
# INFO: Adding line at t = 0.2222222222222222
# INFO:       Calculating line for N = 10
# INFO: Adding line at t = 0.3333333333333333
# INFO:       Calculating line for N = 10
# INFO: Adding line at t = 0.4444444444444444
# INFO:       Calculating line for N = 10
# INFO: Adding line at t = 0.5555555555555556
# INFO:       Calculating line for N = 10
# INFO: Adding line at t = 0.6666666666666666
# INFO:       Calculating line for N = 10
# INFO: Adding line at t = 0.7777777777777777
# INFO:       Calculating line for N = 10
# INFO: Adding line at t = 0.8888888888888888
# INFO:       Calculating line for N = 10
# INFO: Adding line at t = 1.0
# INFO:       Calculating line for N = 10
# INFO: Convergence criteria fulfilled for 9 of 9 neighbouring lines.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
#
# +----------------------------------------------------------------------+
# |                         ==================                           |
# |                         CONVERGENCE REPORT                           |
# |                         ==================                           |
# |                                                                      |
# |                         Line Convergence                             |
# |                         ================                             |
# |                                                                      |
# |                             ForceFirstUpdate                         |
# |                             ----------------                         |
# |                             PASSED: 10 of 10                         |
# |                                                                      |
# |                         Surface Convergence                          |
# |                         ===================                          |
# +----------------------------------------------------------------------+
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-132e8d0e2836> in <module>
#      10     ham=verify.haldane_hamiltonian(m,t1,t1/a,phi)
#      11     verify.write_yaehmop_output_from_ham(fname,k_vect,ham)
# ---> 12     c, z = tim.get_topology(fname,ham_type="general")
#      13     chern_.append(c)
#      14     z2_.append(z)
#
# ~\Documents\argonne\topology_interface\topological_diagnosis\topology_interface_main.py in get_topology(filename, ham_type, surfaces, n)
#     688
#     689         chern_=z2pack.invariant.chern(result)
# --> 690         z2_=z2pack.invariant.z2(result, check_kramers_pairs=False)
#     691
#     692         return chern_, z2_
#
# TypeError: z2() got an unexpected keyword argument 'check_kramers_pairs'

# %% [markdown]
# # 2D: Bernevig Hughes Zhang model

# %%
Image(filename="bhz_ham.png")

# %%
alpha=np.arange(-1.0,1.0,0.1)


fname="bhz_output.OUT"
chern_=[]
z2_=[]
for a in alpha:
    k_vect=tim.generate_k_2D(nkx=10,nky=10,max_kx=0.5)
    ham=verify.bhz(0.5, 1, 0., 0, a)
    verify.write_yaehmop_output_from_ham(fname,k_vect,ham)
    c, z = tim.get_topology(fname,ham_type="general")
    chern_.append(c)
    z2_.append(z)
chern_=np.array(chern_)
z2_=np.array(z2_)

plt.plot(alpha,z2_)
plt.title("plotting z2 of bhz model as is varied relative to relative mass")
plt.xlabel("relative mass")
plt.ylabel("z2 invariant")
plt.show()
# Out:
# +----------------------------------------------------------------------+
# |===================                                                   |
# |SURFACE CALCULATION                                                   |
# |===================                                                   |
# |starting at 2021-08-06 10:14:24,584                                   |
# |running Z2Pack version 2.1.1                                          |
# |                                                                      |
# |gap_tol:            None                                              |
# |init_result:        None                                              |
# |iterator:           range(10, 40)                                     |
# |load:               False                                             |
# |load_quiet:         True                                              |
# |min_neighbour_dist: 0.01                                              |
# |move_tol:           None                                              |
# |num_lines:          10                                                |
# |pos_tol:            None                                              |
# |save_file:          None                                              |
# |serializer:         auto                                              |
# |surface:            <function get_topology<...><lambda> at 0x0B8CAFA8>|
# |system:             <z2pack.hm.System object at 0x0B8E7D50>           |
# +----------------------------------------------------------------------+
#
# INFO: Adding lines required by 'num_lines'.
# INFO: Adding line at t = 0.0
# INFO:       Calculating line for N = 10
# INFO: Adding line at t = 0.1111111111111111
# INFO:       Calculating line for N = 10
# INFO: Adding line at t = 0.2222222222222222
# INFO:       Calculating line for N = 10
# INFO: Adding line at t = 0.3333333333333333
# INFO:       Calculating line for N = 10
# INFO: Adding line at t = 0.4444444444444444
# INFO:       Calculating line for N = 10
# INFO: Adding line at t = 0.5555555555555556
# INFO:       Calculating line for N = 10
# INFO: Adding line at t = 0.6666666666666666
# INFO:       Calculating line for N = 10
# INFO: Adding line at t = 0.7777777777777777
# INFO:       Calculating line for N = 10
# INFO: Adding line at t = 0.8888888888888888
# INFO:       Calculating line for N = 10
# INFO: Adding line at t = 1.0
# INFO:       Calculating line for N = 10
# INFO: Convergence criteria fulfilled for 9 of 9 neighbouring lines.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
#
# +----------------------------------------------------------------------+
# |                         ==================                           |
# |                         CONVERGENCE REPORT                           |
# |                         ==================                           |
# |                                                                      |
# |                         Line Convergence                             |
# |                         ================                             |
# |                                                                      |
# |                             ForceFirstUpdate                         |
# |                             ----------------                         |
# |                             PASSED: 10 of 10                         |
# |                                                                      |
# |                         Surface Convergence                          |
# |                         ===================                          |
# +----------------------------------------------------------------------+
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-641de0b622f0> in <module>
#      13     ham=verify.bhz(0.5, 1, 0., 0, a)
#      14     verify.write_yaehmop_output_from_ham(fname,k_vect,ham)
# ---> 15     c, z = tim.get_topology(fname,ham_type="general")
#      16     chern_.append(c)
#      17     z2_.append(z)
#
# ~\Documents\argonne\topology_interface\topological_diagnosis\topology_interface_main.py in get_topology(filename, ham_type, surfaces, n)
#     586
#     587         chern_=z2pack.invariant.chern(result)
# --> 588         z2_=z2pack.invariant.z2(result, check_kramers_pairs=False)
#     589
#     590         return chern_, z2_
#
# TypeError: z2() got an unexpected keyword argument 'check_kramers_pairs'

# %% [markdown]
# # 3D BHZ Model

# %%
mass=np.arange(-1,1,0.2)
z2_=[]
bhz_edge_surfaces=np.array([[(1,1),(0,1/2),(0,1)],
                        [(0,1/2),(1,1),(0,1)],
                        [(0,1/2),(0,1),(1,1)],
                        [(0,0),(0,1/2),(0,1)],
                        [(0,1/2),(0,0),(0,1)],
                        [(0,1/2),(0,1),(0,0)],
                        ])
n=10
fname="bhz_output3d.OUT"
for m in mass:
    k_vect=tim.generate_k_3D(n=n,surfaces=bhz_edge_surfaces)
    ham=verify.bhz_3D(.5, 1,0,0, m) 
    verify.write_yaehmop_output_from_ham(fname,k_vect,ham)
    z  = tim.get_topology(fname,ham_type="general",surfaces=bhz_edge_surfaces,n=n)
    z2_.append(z)
z2_=np.array(z2_)
print(z2_)
plt.plot(mass,z2_[:,0])
plt.title("plotting strong index (first) z2 of bhz model, varied w/ relative mass")
plt.xlabel("relative mass")
plt.ylabel("z2 invariant")
plt.show()
# Out:
# +----------------------------------------------------------------------+
# | ===================                                                  |
# | SURFACE CALCULATION                                                  |
# | ===================                                                  |
# | starting at 2021-08-06 10:11:13,582                                  |
# | running Z2Pack version 2.1.1                                         |
# |                                                                      |
# | gap_tol:            None                                             |
# | init_result:        None                                             |
# | iterator:           range(10, 40)                                    |
# | load:               False                                            |
# | load_quiet:         True                                             |
# | min_neighbour_dist: 0.01                                             |
# | move_tol:           None                                             |
# | num_lines:          10                                               |
# | pos_tol:            None                                             |
# | save_file:          None                                             |
# | serializer:         auto                                             |
# | surface:            <function z2_3d.<locals>.<lambda> at 0x0BBD7DF8> |
# | system:             <z2pack.hm.System object at 0x0BBBDCD0>          |
# +----------------------------------------------------------------------+
#
# INFO: Adding lines required by 'num_lines'.
# INFO: Adding line at t = 0.0
# INFO:       Calculating line for N = 10
# INFO: Adding line at t = 0.1111111111111111
# INFO:       Calculating line for N = 10
# INFO: Adding line at t = 0.2222222222222222
# INFO:       Calculating line for N = 10
# INFO: Adding line at t = 0.3333333333333333
# INFO:       Calculating line for N = 10
# INFO: Adding line at t = 0.4444444444444444
# INFO:       Calculating line for N = 10
# INFO: Adding line at t = 0.5555555555555556
# INFO:       Calculating line for N = 10
# INFO: Adding line at t = 0.6666666666666666
# INFO:       Calculating line for N = 10
# INFO: Adding line at t = 0.7777777777777777
# INFO:       Calculating line for N = 10
# INFO: Adding line at t = 0.8888888888888888
# INFO:       Calculating line for N = 10
# INFO: Adding line at t = 1.0
# INFO:       Calculating line for N = 10
# INFO: Convergence criteria fulfilled for 9 of 9 neighbouring lines.
#
# +----------------------------------------------------------------------+
# |                   Calculation finished in 0h 0m 0s                   |
# +----------------------------------------------------------------------+
#
# +----------------------------------------------------------------------+
# |                         ==================                           |
# |                         CONVERGENCE REPORT                           |
# |                         ==================                           |
# |                                                                      |
# |                         Line Convergence                             |
# |                         ================                             |
# |                                                                      |
# |                             ForceFirstUpdate                         |
# |                             ----------------                         |
# |                             PASSED: 10 of 10                         |
# |                                                                      |
# |                         Surface Convergence                          |
# |                         ===================                          |
# +----------------------------------------------------------------------+
# C:\Users\danpa\Documents\argonne\topology_interface\topological_diagnosis\topology_interface_main.py:595: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if surfaces=="default":
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-6f871e201c7f> in <module>
#      14     ham=verify.bhz_3D(.5, 1,0,0, m)
#      15     verify.write_yaehmop_output_from_ham(fname,k_vect,ham)
# ---> 16     z  = tim.get_topology(fname,ham_type="general",surfaces=bhz_edge_surfaces,n=n)
#      17     z2_.append(z)
#      18 z2_=np.array(z2_)
#
# ~\Documents\argonne\topology_interface\topological_diagnosis\topology_interface_main.py in get_topology(filename, ham_type, surfaces, n)
#     601                             [(0,1),(0,1),(0,0)],
#     602                             ])
# --> 603         z2_indices=z2_3d(system,n,surfaces)
#     604
#     605
#
# ~\Documents\argonne\topology_interface\topological_diagnosis\topology_interface_main.py in z2_3d(system, n, surfaces)
#     380             )
#     381
# --> 382         z2_[i]=z2pack.invariant.z2(result, check_kramers_pairs=False)
#     383
#     384     n4_n1=abs(z2_[3]+z2_[0])%2
#
# TypeError: z2() got an unexpected keyword argument 'check_kramers_pairs'

# %% [markdown]
# # Using interface to detect topologically non-trivial materials from POSCAR files

# %%
input_POSCAR="bhz_output3d.OUT"

#get topology of Yaehmop output file structure

output_yaehmop_filename="mp-47.OUT"
z2_ = tim.get_topology(output_yaehmop_filename)
print(z2_)
# Out:
# +----------------------------------------------------------------------+
# | ===================                                                  |
# | SURFACE CALCULATION                                                  |
# | ===================                                                  |
# | starting at 2021-08-04 15:45:12,461                                  |
# | running Z2Pack version 2.1.1                                         |
# |                                                                      |
# | gap_tol:            None                                             |
# | init_result:        None                                             |
# | iterator:           range(17, 40)                                    |
# | load:               False                                            |
# | load_quiet:         True                                             |
# | min_neighbour_dist: 0.01                                             |
# | move_tol:           None                                             |
# | num_lines:          34                                               |
# | pos_tol:            None                                             |
# | save_file:          None                                             |
# | serializer:         auto                                             |
# | surface:            <function z2_3d.<locals>.<lambda> at 0x05F1C270> |
# | system:             <z2pack.hm.System object at 0x0B342E50>          |
# +----------------------------------------------------------------------+
#
# INFO: Adding lines required by 'num_lines'.
# INFO: Adding line at t = 0.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-90a7f3bd8172> in <module>
#      10
#      11 output_yaehmop_filename="mp-47.OUT"
# ---> 12 c_,z2_= tim.get_topology(output_yaehmop_filename)
#      13 print(c_)
#      14 print(z2_)
#
# ~\Documents\argonne\topology_interface\topological_diagnosis\topology_interface_main.py in get_topology(filename, ham_type)
#     564
#     565         chern_=0 #get_All_ChernNumbers(result)
# --> 566         z2_indices= z2_3d(system,nkx=nkx,nky=nky,nkz=nkz,maxkx=maxkx,maxky=maxky)
#     567         return chern_, z2_indices
#     568
#
# ~\Documents\argonne\topology_interface\topological_diagnosis\topology_interface_main.py in z2_3d(system, nkx, nky, nkz, maxkx, maxky)
#     368             move_tol=None,
#     369             num_lines=nky, #**yexpon ,
# --> 370             iterator=range((nkz)+1,40)
#     371             )
#     372
#
# ~\AppData\Roaming\Python\Python37\site-packages\z2pack\surface\_run.py in run_surface(system, surface, pos_tol, gap_tol, move_tol, num_lines, min_neighbour_dist, iterator, init_result, save_file, load, load_quiet, serializer)
#     147         save_file=save_file,
#     148         init_result=init_result,
# --> 149         serializer=serializer
#     150     )
#     151
#
# ~\anaconda3\lib\contextlib.py in inner(*args, **kwds)
#      72         def inner(*args, **kwds):
#      73             with self._recreate_cm():
# ---> 74                 return func(*args, **kwds)
#      75         return inner
#      76
#
# ~\AppData\Roaming\Python\Python37\site-packages\z2pack\surface\_run.py in _run_surface_impl(system, surface, num_lines, min_neighbour_dist, save_file, init_result, serializer, *controls)
#     275         _LOGGER.info("Adding lines required by 'num_lines'.")
#     276         for t in np.linspace(0, 1, num_lines):
# --> 277             result = add_line(t)
#     278
#     279         # STEP 3 -- MAIN LOOP
#
# ~\AppData\Roaming\Python\Python37\site-packages\z2pack\surface\_run.py in add_line(t)
#     219
#     220             _LOGGER.info('Adding line at t = {}'.format(t))
# --> 221             data.add_line(t, get_line(t))
#     222
#     223             return update_result()
#
# ~\AppData\Roaming\Python\Python37\site-packages\z2pack\surface\_run.py in get_line(t, init_line_result)
#     192             system=system,
#     193             line=lambda ky: surface(t, ky),
# --> 194             init_result=init_line_result
#     195         )
#     196
#
# ~\AppData\Roaming\Python\Python37\site-packages\z2pack\line\_run.py in _run_line_impl(system, line, save_file, init_result, serializer, *controls)
#     142     delta = np.array(line(1)) - np.array(line(0))
#     143     if not np.isclose(np.round_(delta), delta).all():
# --> 144         raise ValueError('Start and end points of the line differ by {}, which is not an inverse lattice vector.'.format(delta))
#     145
#     146     # check if all controls are valid
#
# ValueError: Start and end points of the line differ by [0.     0.     0.3333], which is not an inverse lattice vector.
